# %%
import pandas as pd
import numpy as np
import sklearn.datasets
from factor_analyzer import FactorAnalyzer
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\anesa\Downloads\Car_Survey.csv")

# %%
df.head()
# Out:
#    ID  Price  Safety  Exterior_Looks  Space_comfort  Technology  \
# 0  R1      4       4               5              4           3
# 1  R2      3       5               3              3           4
# 2  R3      4       4               3              4           5
# 3  R4      4       4               4              3           3
# 4  R5      5       5               4              4           5
#
#    After_Sales_Service  Resale_Value  Fuel_Type  Mileage  Color  Maintenance  \
# 0                    4             5          4        4      2            4
# 1                    4             3          4        3      4            3
# 2                    5             5          4        5      4            5
# 3                    4             5          5        4      4            4
# 4                    4             5          3        4      5            5
#
#    Test_drive  Product_reviews  Testimonials
# 0           2                4             3
# 1           2                2             2
# 2           4                4             3
# 3           2                5             3
# 4           5                5             2

# %%
df=df.iloc[0:,1:]

# %%
df.head()
# Out:
#    Price  Safety  Exterior_Looks  Space_comfort  Technology  \
# 0      4       4               5              4           3
# 1      3       5               3              3           4
# 2      4       4               3              4           5
# 3      4       4               4              3           3
# 4      5       5               4              4           5
#
#    After_Sales_Service  Resale_Value  Fuel_Type  Mileage  Color  Maintenance  \
# 0                    4             5          4        4      2            4
# 1                    4             3          4        3      4            3
# 2                    5             5          4        5      4            5
# 3                    4             5          5        4      4            4
# 4                    4             5          3        4      5            5
#
#    Test_drive  Product_reviews  Testimonials
# 0           2                4             3
# 1           2                2             2
# 2           4                4             3
# 3           2                5             3
# 4           5                5             2

# %%
fa= FactorAnalyzer(n_factors=4,rotation="varimax")

# %%
df=df.dropna()

# %%
fa.fit(df)
# Out:
# FactorAnalyzer(n_factors=4, rotation='varimax', rotation_kwargs={})

# %%
loadings=fa.loadings_

# %%
ev, v=fa.get_eigenvalues()

# %%
xvals= range(1, df.shape[1]+1)

# %%
plt.scatter(xvals,ev)
plt.plot(xvals, ev)
plt.title('screen plot')
plt.xlabel('Factor')
plt.ylabel('Eigenvalue')
plt.grid()
plt.show()

# %%
pd.DataFrame.from_records(loadings)
# Out:
#            0         1         2         3
# 0   0.534736  0.109819 -0.003190 -0.050199
# 1  -0.271603  0.355607 -0.175106  0.060454
# 2  -0.004915  0.044894  0.192741 -0.544145
# 3  -0.028290  0.752958  0.219524 -0.222665
# 4   0.042966  0.349019  0.103184  0.013715
# 5   0.163276  0.527969  0.102347  0.123956
# 6   0.723571 -0.142859 -0.137286  0.058073
# 7   0.044477  0.556858 -0.000123 -0.069066
# 8   0.492075  0.234735  0.299064  0.291384
# 9   0.197921 -0.028712  0.265966  0.706008
# 10  0.602593  0.078714  0.110756  0.233411
# 11  0.098187  0.150255  0.406842 -0.018346
# 12  0.336044  0.144764  0.428927  0.032276
# 13 -0.228305 -0.007628  0.676960  0.001049
